# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
# List down the features and their types (e.g., numeric, nominal) available in the dataset.

# sepal_length: Numeric (Continuous)
# sepal_width: Numeric (Continuous)
# petal_length: Numeric (Continuous)
# petal_width: Numeric (Continuous)
# species: Nominal (Categorical)

# %%
plt.hist(df['sepal_length'], bins=10, color='skyblue', edgecolor='black')
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
print(df['sepal_length'].min(),df['sepal_length'].max())
# Out:
# 4.3 7.9

# %%
plt.hist(df['sepal_width'], bins=10, color='skyblue', edgecolor='black')
# Out:
# (array([ 4.,  7., 22., 24., 37., 31., 10., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['petal_length'], bins=10, color='skyblue', edgecolor='black')
# Out:
# (array([37., 13.,  0.,  3.,  8., 26., 29., 18., 11.,  5.]),
#  array([1.  , 1.59, 2.18, 2.77, 3.36, 3.95, 4.54, 5.13, 5.72, 6.31, 6.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['petal_width'], bins=10, color='skyblue', edgecolor='black')
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['species'], bins=10, color='skyblue', edgecolor='black')
# Out:
# (array([50.,  0.,  0.,  0.,  0., 50.,  0.,  0.,  0., 50.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
sns.boxplot(df['sepal_length'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['sepal_width'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['petal_length'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['petal_width'])
# Out:
# <Axes: >

# %%
sns.boxplot(data = df)
# Out:
# <Axes: >

# %%
# outliers
numeric_col = df.drop(columns = 'species')
Q1 = numeric_col.quantile(0.25)
Q3 = numeric_col.quantile(0.75)

IQR = Q3 - Q1

outliers = ((numeric_col < (Q1 - 1.5 * IQR)) | (numeric_col > (Q3 + 1.5 * IQR))).any(axis=1)

outliers_count = outliers.sum()

print("Number of outliers : ", outliers_count)
print("Indices of outliers : ", df[outliers].index)
# Out:
# Number of outliers :  4
# Indices of outliers :  Index([15, 32, 33, 60], dtype='int64')
